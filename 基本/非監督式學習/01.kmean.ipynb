# %% [markdown]
# #### K means
# 參考資料:
# *  https://medium.com/analytics-vidhya/to-start-with-k-means-clustering-1c6ee3cb840f

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))  #新增畫布,設定大小
plt.imshow(plt.imread("D:/github/圖片/K_means.PNG"))
plt.axis('off') #關閉座標
plt.show()
